# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## This notebook displays the example .csv for spaCy sentiment and Named Entity Recognition

# %%
df = pd.read_csv("../csvs/processed/example_linkedin_jobs_processed.csv",index_col=0)
df.head()
# Out:
#                                                           company  \
# title
# Full Stack - Software Engineer (L5) - Platform ...        Netflix
# Frontend Engineer                                          Porter
# Frontend Developer                                      Adapty.io
# Front-End / Full-Stack Developer                          Corsair
# Junior Web Developer                                IntelliBridge
#
#                                                           location  \
# title
# Full Stack - Software Engineer (L5) - Platform ...   Los Gatos, CA
# Frontend Engineer                                     New York, NY
# Frontend Developer                                   United States
# Front-End / Full-Stack Developer                      Milpitas, CA
# Junior Web Developer                                Washington, DC
#
#                                                                                                   url  \
# title
# ...

# %%
# Example plot
df['company'].value_counts().plot(kind='bar')
plt.title('Job Postings by Company')
plt.ylabel('Number of Job Postings')
plt.savefig('job_postings_by_company.png')
